# %%
# Install Libraries
# !pip install textblob
# !pip install tweepy
# !pip install pycountry
# !pip install wordcloud
# !pip install langdetect
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      -------------------------------------- 636.8/636.8 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.1 in c:\users\sivasai\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in c:\users\sivasai\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sivasai\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: joblib in c:\users\sivasai\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.1)
# Requirement already satisfied: click in c:\users\sivasai\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in c:\users\sivasai\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# Installing collected packages: textblob
# Successfully installed textblob-0.17.1
# Collecting tweepy
#   Downloading tweepy-4.14.0-py3-none-any.whl (98 kB)
#      -------------------------------------- 98.5/98.5 kB 706.2 kB/s eta 0:00:00
# Collecting requests-oauthlib<2,>=1.2.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\sivasai\anaconda3\lib\site-packages (from tweepy) (2.28.1)
# Collecting oauthlib<4,>=3.2.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sivasai\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sivasai\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sivasai\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sivasai\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.12.7)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.2 requests-oauthlib-1.3.1 tweepy-4.14.0
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      ---------------------------------------- 10.1/10.1 MB 7.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\sivasai\anaconda3\lib\site-packages (from pycountry) (65.6.3)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (pyproject.toml): started
#   Building wheel for pycountry (pyproject.toml): finished with status 'done'
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681896 sha256=bc369cc96fb9fe8f356ae528ff930caf64aef042f67ba457fa03fbc6668aeb10
#   Stored in directory: c:\users\sivasai\appdata\local\pip\cache\wheels\62\4a\9c\7a46699df9efb845aa116fae5e52d8690fc442fef6d32213f7
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5
# Collecting wordcloud
#   Downloading wordcloud-1.9.1.1-cp310-cp310-win_amd64.whl (152 kB)
#      -------------------------------------- 152.1/152.1 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\sivasai\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\sivasai\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sivasai\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sivasai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sivasai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sivasai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sivasai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sivasai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sivasai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sivasai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\sivasai\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.1.1
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      -------------------------------------- 981.5/981.5 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in c:\users\sivasai\anaconda3\lib\site-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993253 sha256=8c9c9a737c9d443fcfc942839719a43c5e40264fab52abaf5f07f6fc6e3d4e83
#   Stored in directory: c:\users\sivasai\appdata\local\pip\cache\wheels\c4\16\af\1889804d8b7c0c041cadee8e29673a938a332acbf2865c70a1
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
# Import Libraries

from textblob import TextBlob
import sys
import tweepy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sivasai\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# # Step 2: Authentication for Twitter API

# %%
# Authentication
consumerKey = "2CJbp8m7Rg26LtZEKAeVXWceG"
consumerSecret = "IbULWKlS0uvhLnMTcFkzvMjDfZUcBM6eVbdLYMUbNafhieX8Y6"
accessToken = "1119095264961126402-8QDK0FvTjGmV7w1hUtGsTyCyH77bNE"
accessTokenSecret = "unheMaBnZsHrcBt3mK1bE8Ib4wtE3tPtAwSA65Y0zWIK0"

auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %% [markdown]
# # Step 3: Getting Tweets With Keyword or Hashtag

# %%
#Sentiment Analysis
def percentage(part,whole):
    return 100 * float(part)/float(whole) 

keyword = input("Please enter keyword or hashtag to search: ")
noOfTweet = int(input ("Please enter how many tweets to analyze: "))

tweets = tweepy.Cursor(api.search_tweets, q=keyword).items(noOfTweet)
positive  = 0
negative = 0
neutral = 0
polarity = 0
tweet_list = []
neutral_list = []
negative_list = []
positive_list = []

for tweet in tweets:
    # print(tweet.text)
    tweet_list.append(tweet.text)
    analysis = TextBlob(tweet.text)
    score = SentimentIntensityAnalyzer().polarity_scores(tweet.text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    polarity += analysis.sentiment.polarity
    
    if neg > pos:
        negative_list.append(tweet.text)
        negative += 1

    elif pos > neg:
        positive_list.append(tweet.text)
        positive += 1
    
    elif pos == neg:
        neutral_list.append(tweet.text)
        neutral += 1

positive = percentage(positive, noOfTweet)
negative = percentage(negative, noOfTweet)
neutral = percentage(neutral, noOfTweet)
polarity = percentage(polarity, noOfTweet)
positive = format(positive, '.1f')
negative = format(negative, '.1f')
neutral = format(neutral, '.1f')
# Out:
# Please enter keyword or hashtag to search: UCM
# Please enter how many tweets to analyze: 150

# %%
#Number of Tweets (Total, Positive, Negative, Neutral)
tweet_list = pd.DataFrame(tweet_list)
neutral_list = pd.DataFrame(neutral_list)
negative_list = pd.DataFrame(negative_list)
positive_list = pd.DataFrame(positive_list)
print("total number: ",len(tweet_list))
print("positive number: ",len(positive_list))
print("negative number: ", len(negative_list))
print("neutral number: ",len(neutral_list))
# Out:
# total number:  150
# positive number:  27
# negative number:  77
# neutral number:  46

# %%
tweet_list[0:20]
# Out:
#                                                     0
# 0   RT @peterjordan100: Geral falando bem de Guard...
# 1   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 2   ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...
# 3   👉🏻 Después de #DoctorStrangeInTheMultiverseOMa...
# 4   RT @peterjordan100: Geral falando bem de Guard...
# 5   RT @peterjordan100: Geral falando bem de Guard...
# 6   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 7   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 8   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 9   @elianchico9070 @Soy_Sense @MarvelLatin Porqué...
# 10  RT @Multiverso_GK: Y así cierra, una de las me...
# 11  RT @peterjordan100: Geral falando bem de Guard...
# 12  RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 13  RT @YulierSarria: En la #UCM de #Cienfuegos se...
# 14  RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 15  RT @peterjordan100: Geral falando bem de Guard...
# 16  RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 17  RT @lpuchg: Afiliación a la Seguridad Social e...
# 18  RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 19  RT @peterjordan100: Geral falando bem de Guard...

# %%
#Creating PieCart

labels = ['Positive ['+str(positive)+'%]' , 'Neutral ['+str(neutral)+'%]','Negative ['+str(negative)+'%]']
sizes = [positive, neutral, negative]
colors = ['yellowgreen', 'blue','red']
patches, texts = plt.pie(sizes,colors=colors, startangle=90)
plt.style.use('default')
plt.legend(labels)
plt.title("Sentiment Analysis Result for keyword=  "+keyword+"" )
plt.axis('equal')
plt.show()

# %%
tweet_list.drop_duplicates(inplace = True)

# %% [markdown]
# # Extracting text values

# %%
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]
tw_list
# Out:
#                                                      0  \
# 0    RT @peterjordan100: Geral falando bem de Guard...
# 1    RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 2    ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...
# 3    👉🏻 Después de #DoctorStrangeInTheMultiverseOMa...
# 9    @elianchico9070 @Soy_Sense @MarvelLatin Porqué...
# 10   RT @Multiverso_GK: Y así cierra, una de las me...
# 13   RT @YulierSarria: En la #UCM de #Cienfuegos se...
# 17   RT @lpuchg: Afiliación a la Seguridad Social e...
# 21   Guardianes de la Galaxia Vol. 3 llego para dar...
# 25   ¿A ti también te preocupa la #IA? ¿Por qué no ...
# 27   RT @Ian4Star: Bueno señores hoy toca ver #Guar...
# 28   RT @MarvelDato: 🍿 | ¿Del 1 al 10, qué notan le...
# 29   @AgentedeMarvel_ Otra película totalmente mach...
# 31   RT @MarvelLatin: Top 5 VILLANOS del UCM https:...
# 33   @ArgieViBritania Sin temblarme el pulso diría ...
# 37   RT @julieta_aramayo: @_NovelaGrafica Para mí s...
# 48   @J4viiKal Con Quantumania es cuando dije "hast...
# 51   @EnriiqueM_ Ay Dios… pa mi es la trilogía más ...
# 53   RT @MarvelLatin: Luego de analizarlo\n\n#Guard...
# %%
#Cleaning Text (RT, Punctuation etc)

#Creating new dataframe and new features
tw_list = pd.DataFrame(tweet_list)
tw_list["text"] = tw_list[0]

#Removing RT, Punctuation etc
remove_rt = lambda x: re.sub('RT @\w+: '," ",x)
rt = lambda x: re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",x)
tw_list["text"] = tw_list.text.map(remove_rt).map(rt)
tw_list["text"] = tw_list.text.str.lower()
tw_list.head(10)
# Out:
#                                                     0  \
# 0   RT @peterjordan100: Geral falando bem de Guard...
# 1   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 2   ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...
# 3   👉🏻 Después de #DoctorStrangeInTheMultiverseOMa...
# 9   @elianchico9070 @Soy_Sense @MarvelLatin Porqué...
# 10  RT @Multiverso_GK: Y así cierra, una de las me...
# 13  RT @YulierSarria: En la #UCM de #Cienfuegos se...
# 17  RT @lpuchg: Afiliación a la Seguridad Social e...
# 21  Guardianes de la Galaxia Vol. 3 llego para dar...
# 25  ¿A ti también te preocupa la #IA? ¿Por qué no ...
#
#                                                  text
# 0    geral falando bem de guardi es da gal xia  ge...
# 1     en honor a star wars    por el  maythe4thbew...
# 2   es la mejor  una de mis favoritas del ucm
# 3      despu s de  doctorstrangeinthemultiverseoma...
# 9       sense   porqu  no  a fin de cuentas estuvo...
# 10   y as  cierra  una de las mejores trilog as de...
# 13   en la  ucm de  cienfuegos se realiz  en la ma...
# 17   afiliaci n a la seguridad social en datos dia...
# 21  guardianes de la galaxia vol  3 llego para dar...
# 25   a ti tambi n te preocupa la  ia   por qu  no ...

# %%
#Calculating Negative, Positive, Neutral and Compound values

tw_list[['polarity', 'subjectivity']] = tw_list['text'].apply(lambda Text: pd.Series(TextBlob(Text).sentiment))
for index, row in tw_list['text'].iteritems():
    score = SentimentIntensityAnalyzer().polarity_scores(row)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    comp = score['compound']
    if neg > pos:
        tw_list.loc[index, 'sentiment'] = "negative"
    elif pos > neg:
        tw_list.loc[index, 'sentiment'] = "positive"
    else:
        tw_list.loc[index, 'sentiment'] = "neutral"
    tw_list.loc[index, 'neg'] = neg
    tw_list.loc[index, 'neu'] = neu
    tw_list.loc[index, 'pos'] = pos
    tw_list.loc[index, 'compound'] = comp

tw_list.head(10)
# Out:
# C:\Users\sivasai\AppData\Local\Temp\ipykernel_16204\4219357815.py:4: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for index, row in tw_list['text'].iteritems():
#                                                     0  \
# 0   RT @peterjordan100: Geral falando bem de Guard...
# 1   RT @GabyMeza8: ¡EN HONOR A STAR WARS! 🙌 Por el...
# 2   ES LA MEJOR, UNA DE MIS FAVORITAS DEL UCM 👏🏼❤️...
# 3   👉🏻 Después de #DoctorStrangeInTheMultiverseOMa...
# 9   @elianchico9070 @Soy_Sense @MarvelLatin Porqué...
# 10  RT @Multiverso_GK: Y así cierra, una de las me...
# 13  RT @YulierSarria: En la #UCM de #Cienfuegos se...
# 17  RT @lpuchg: Afiliación a la Seguridad Social e...
# 21  Guardianes de la Galaxia Vol. 3 llego para dar...
# 25  ¿A ti también te preocupa la #IA? ¿Por qué no ...
#
#                                                  text  polarity  subjectivity  \
# 0    geral falando bem de guardi es da gal xia  ge...  0.000000      0.000000
# 1     en honor a star wars    por el  maythe4thbew...  0.000000      0.066667
# 2   es la mejor  una de mis favoritas del ucm          0.000000      0.000000
# 3      despu s de  doctorstrangeinthemultiverseoma...  0.000000      0.000000
# 9       sense   porqu  no  a fin de cuentas estuvo...  0.000000      0.000000
# 10   y as  cierra  una de las mejores trilog as de...  0.000000      0.000000
# 13   en la  ucm de  cienfuegos se realiz  en la ma...  0.000000      0.000000
# 17   afiliaci n a la seguridad social en datos dia...  0.033333      0.066667
# 21  guardianes de la galaxia vol  3 llego para dar...  0.000000      0.000000
# 25   a ti tambi n te preocupa la  ia   por qu  no ...  0.000000      0.000000
#
#    sentiment    neg    neu    pos  compound
# 0    neutral  0.000  1.000  0.000    0.0000
# 1   negative  0.165  0.688  0.147   -0.1027
# 2    neutral  0.000  1.000  0.000    0.0000
# 3    neutral  0.000  1.000  0.000    0.0000
# 9   negative  0.196  0.804  0.000   -0.2960
# 10   neutral  0.000  1.000  0.000    0.0000
# 13   neutral  0.000  1.000  0.000    0.0000
# 17  negative  0.159  0.841  0.000   -0.5574
# 21   neutral  0.000  1.000  0.000    0.0000
# 25  negative  0.128  0.872  0.000   -0.2960

# %%
#Creating new data frames for all sentiments (positive, negative and neutral)

tw_list_negative = tw_list[tw_list["sentiment"]=="negative"]
tw_list_positive = tw_list[tw_list["sentiment"]=="positive"]
tw_list_neutral = tw_list[tw_list["sentiment"]=="neutral"]

# %%
#Function for count_values_in single columns

def count_values_in_column(data,feature):
    total=data.loc[:,feature].value_counts(dropna=False)
    percentage=round(data.loc[:,feature].value_counts(dropna=False,normalize=True)*100,2)
    return pd.concat([total,percentage],axis=1,keys=['Total','Percentage'])

# %%
#Count_values for sentiment
count_values_in_column(tw_list,"sentiment")
# Out:
#           Total  Percentage
# neutral      22       53.66
# negative     10       24.39
# positive      9       21.95

# %%
# create data for Pie Chart
pc = count_values_in_column(tw_list,"sentiment")
names= pc.index
size=pc["Percentage"]
 
# Create a circle for the center of the plot
my_circle=plt.Circle( (0,0), 0.7, color='white')
plt.pie(size, labels=names, colors=['green','blue','red'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
#Function to Create Wordcloud

def create_wordcloud(text):
    stopwords = set(STOPWORDS)
    wc = WordCloud(background_color="white", width=600, height=400,               
                  max_words=300,
                  stopwords=stopwords,
                  repeat=True)
    wc.generate(str(text))
    
    plt.imshow(wc)
    plt.show()

# %%
#Creating wordcloud for all tweets
create_wordcloud(tw_list["text"].values)

# %%
#Creating wordcloud for positive sentiment
create_wordcloud(tw_list_positive["text"].values)

# %%
#Creating wordcloud for negative sentiment
create_wordcloud(tw_list_negative["text"].values)

# %%
#Creating wordcloud for neutral sentiment
create_wordcloud(tw_list_neutral["text"].values)
